# %%
class Phone:
    #constructor  
    def __init__(self, model, battery):
        self.model = model
        self.battery = battery


apple = Phone("iPhone17", 100)
motorola = Phone("MotoG", 80)

print(apple.model)
print(apple.battery)

print(motorola.model)
print(motorola.battery)
# Out:
# iPhone17
# 100
# MotoG
# 80

# %%
class Phone:
    category = "Electronics"   #class variable

    def __init__(self, model):  #self.variable
        self.model = model


p1 = Phone("iPhone")
p2 = Phone("Samsung")

print(p1.category,p1.model)
print(p2.category,p2.model)
# Out:
# Electronics iPhone
# Electronics Samsung

# %%
   #Type	              #meaning
#class variable	   #সবাই share করে
#self.variable	      #object এর নিজস্ব

#C++:

#👉 “সব কিছু আগে declare + constructor এ set”

#Python:

#👉 “চাও তো class এ direct লিখো, চাও তো constructor এ দাও”

# %%
# base class / parent class
class Phone:
  category = "Electronics"  # class attribute 

  # constructor
  def __init__(self,model , battery , camera,battery_percentage=100):
    self.model = model   #instance attribute
    self.battery = battery  #instance attribute
    self.camera = camera  #instance attribute
    self.battery_percentage = battery_percentage #instance attribute

  # instance methods
  def charge(self,hour):
    print(f"charge completed by {hour}")

  def capture(self,photo):
    if(self.battery_percentage)<=0:
      print("No charge")
    else:
      self.battery_percentage-=photo
      print(self.battery_percentage)
      print(f"photo captured in {self.model}")
## creating object
apple = Phone("Iphone17",3000,40)
blueberry = Phone("B-17",4000,30)
motorola = Phone("M-17",3500,35)
apple.capture(10)
apple.charge(34)
print(motorola.battery_percentage,motorola.model,motorola.battery)
print(apple.battery_percentage,apple.battery,apple.category)
# Out:
# 90
# photo captured in Iphone17
# charge completed by 34
# 100 M-17 3500
# 90 3000 Electronics

# %%
class phone:
    catagory="Electronics"

    def __init__(self, model , battery , camera,battery_percentage=0): 
        self.model=model
        self.battery=battery
        self.camera=camera
        self.battery_percentage=battery_percentage
     
     #method
    def  charge(self,hour):
        print(f"charge is getting by {hour}")  # method  gola jeheto function so obsoi ader function call er based e call
    def capture(self,photo):
        if(self.battery_percentage)<=0:
         print("No charge")
        else:
           self.battery_percentage-=photo
           print(self.battery_percentage)
           print(f"photo will be captured {self.model}")
           
apple=phone("Iphone",3000,60)
samsung=phone("Samsung",3000,60)
vivo=phone("Vivo",3000,60)

apple.capture(10)
samsung.capture(10)
vivo.capture(10)

apple.charge(69)
apple.charge(45)
apple.charge(67)

print(apple.model,apple.battery,apple.camera)  
print(samsung.model,samsung.battery,samsung.camera)  
print(vivo.model,vivo.battery,vivo.camera)
# Out:
# No charge
# No charge
# No charge
# charge is getting by 69
# charge is getting by 45
# charge is getting by 67
# Iphone 3000 60
# Samsung 3000 60
# Vivo 3000 60

# %%
class phone:
    catagory="Electronics"

    def __init__(self, model , battery , camera,battery_percentage=100): 
        self.model=model
        self.battery=battery
        self.camera=camera
        self.battery_percentage=battery_percentage
     
     #method
    def  charge(self,hour):
        print(f"charge is getting by {hour}")  # method  gola jeheto function so obsoi ader function call er based e call
    def capture(self,photo):
        if(self.battery_percentage)<=0:
         print("No charge")
        else:
           self.battery_percentage-=photo
           print(self.battery_percentage)
           print(f"photo will be captured {self.model}")


#single inheritence   
 
class smartphone(phone):
    def __init__(self, model, battery, camera,processor):
       super().__init__(model, battery, camera)  # a moloto phone class dot dia declare kora persone golare call kore dise jeno berber dot diA likte na hoi
       self.processor=processor

   ## modified method
    def charge(self,hour):
       
       print("fast charging in process")
       super().charge(hour)

pro = smartphone("X",5000,100,"SnapDragon")

print(pro.model)
print(pro.battery_percentage)

pro.charge(1)
# Out:
# X
# 100
# fast charging in process
# charge is getting by 1

# %%
# ami nije korsi
class phone:
    def __init__(self,model,battery,camera,battery_percentage=100):
        self.model=model
        self.battery=battery
        self.camera=camera
        self.battery_percentage=battery_percentage

    #method
    def charge(self,hour):
        print(f"the charge is not full without {hour} hour")  
    def capture(self,photo):
        if (self.battery_percentage)>0:  # battery percentage age bolei disi

            print("can  take a picture")
        else:
            print("can not take picture")
             
apple=phone("iphone",100,233) 
apple.capture(12)  
print(apple.model)
# Out:
# can  take a picture
# iphone

# %%
#single inheritance
class smartphone(phone):
    def __init__(self,model,battery,camera,processor): #or nijer ki ki lagbe noton ..
        super().__init__(model,battery,camera)   # milgola parent teke nia nisi
        self.processor=processor       

    #method 
    def charge(self,charge_percentage):
                                            # akne super use korte hoito bt kora lage nai karon parrent teke kico ni nai
        if charge_percentage>0:
            print("no need charge")
            
        else:
            print("need charge")

Smartphone=smartphone("sayed",2000,233,8999)
Smartphone.charge(0)   
print(Smartphone.model)
# Out:
# need charge
# sayed

# %%
#multiple inheritance

class cooling_mechnism:
   def __init__(self,colling_method):
      self.colling_method=colling_method

       
   def colling_method(self):                 # ai method ta create na korleo code same kaj korbe
      print(f"collnig process is gone a be {self.colling_method}")


class smartphone_with_coolinmood(smartphone,cooling_mechnism):
   def __init__(self,model,battery,camera,processor,colling_method):
      smartphone.__init__ (self,model,battery,camera,processor) 
      cooling_mechnism.__init__(self,colling_method)     


pro_mobile=smartphone_with_coolinmood("saifali",2333,70,"sd","sodium")

print(pro_mobile.model)   # phone teke paise
print(pro_mobile.processor)  # ta smartphone teke paise
print(pro_mobile.battery) 
print(pro_mobile.colling_method)
# Out:
# saifali
# sd
# 2333
# sodium

# %%
# parent class
class device:
    def __init__(self, brand, power):
        self.brand = brand
        self.power = power

    def start(self):
        print("Device is starting")


# single inheritance
class laptop(device):
    def __init__(self, brand, power, ram):
        super().__init__(brand, power)
        self.ram = ram

    def start(self):
        super().start()   # parent method call
        print("Laptop is ready")

# another class
class gaming_feature:
    def __init__(self, gpu):
        self.gpu = gpu

    def play_game(self):
        print(f"Game running with {self.gpu}")


# multiple inheritance
class gaming_laptop(laptop, gaming_feature):
    def __init__(self, brand, power, ram, gpu):
        laptop.__init__(self, brand, power, ram)
        gaming_feature.__init__(self, gpu)

# object
g1 = gaming_laptop("Dell", "65W", "16GB", "RTX 4060")

# output
g1.start()
g1.play_game()

print(g1.brand)
print(g1.ram)
print(g1.gpu)
# Out:
# Device is starting
# Laptop is ready
# Game running with RTX 4060
# Dell
# 16GB
# RTX 4060

# %%
# parent class
class car:
    def __init__(self, brand, engine, fuel):
        self.brand = brand
        self.engine = engine
        self.fuel = fuel

    def start(self):
        print("Car is starting")


# single inheritance
class electric_car(car):
    def __init__(self, brand, engine, fuel, battery_capacity):
        super().__init__(brand, engine, fuel)
        self.battery_capacity = battery_capacity

    def start(self):
        super().start()   # parent call
        print("Electric system ready")


# another class
class autopilot_system:
    def __init__(self, version):
        self.version = version

    def auto_drive(self):
        print(f"Autopilot version {self.version} driving")


# multiple inheritance
class tesla(electric_car, autopilot_system):
    def __init__(self, brand, engine, fuel, battery_capacity, version):
        electric_car.__init__(self, brand, engine, fuel, battery_capacity)
        autopilot_system.__init__(self, version)


# object create
t1 = tesla("Tesla", "Dual Motor", "Electric", "100kWh", "v12")

# output
t1.start() # jeheto sby akn tesla te dokse ga tai previous jekono method call korle pai jabo tbe o kinto tesla er first def e takte prbena
t1.auto_drive()

print(t1.brand)
print(t1.battery_capacity)
print(t1.version)
# Out:
# Car is starting
# Electric system ready
# Autopilot version v12 driving
# Tesla
# 100kWh
# v12

# %% [markdown]
# ### polymorphism ###

# %%
class Camera:
  def __init__(self , name):
    self.name = name

 # method
  def capture(self):
    print("a photo is captured")
    
class Smart_Phone(Camera):
  def __init__(self,name,resolution):
    super().__init__(name)
    self.resolution = resolution

  #method overriding
  def capture(self):
    print("Photo is captured by a Phone")
 

class DSLR(Camera):
  def __init__(self,name,resolution):
    super().__init__(name)
    self.resolution = resolution

  def capture(self):
    print("Photo is captured  by DSLR")



class Drone(Camera):
  def __init__(self,name,resolution):
    super().__init__(name)
    self.resolution = resolution

  def capture(self):
    print("Photo is captured by Drone")



phone = Smart_Phone("Phone",30)
dslr = DSLR ("DSLR",200)
drone = Drone("Drone",150)


phone.capture()
dslr.capture()
drone.capture()
# Out:
# Photo is captured by a Phone
# Photo is captured  by DSLR
# Photo is captured by Drone

# %%
class camera:
    def __init__(self,name):
        self.name=name

    def capture(self):
        print(f"captured by the ")

class iphone(camera):  
    def __init__(self,name,resolution):
        super().__init__(name)
        self.resolution=resolution
        
    def capture(self):
        print(f"captured by the {self.name}")

class DSLR(camera):  
    def __init__(self,name,resolution):
        super().__init__(name)
        self.resolution=resolution
        
    def capture(self):
        print(f"captured by the {self.name}")

class Drone(camera):
  def __init__(self,name,resolution):
    super().__init__(name)
    self.resolution = resolution

  def capture(self):
    
    print(f"Photo is captured by {self.name}")

Iphone=iphone("Iphone19",300)
dslr=DSLR("dsLR",300)
drone=Drone("drone",300)


Iphone.capture()
dslr.capture()
drone.capture()
#for obj in [Iphone, dslr, drone]:
    #obj.capture()
# Out:
# captured by the Iphone19
# captured by the dsLR
# Photo is captured by drone

# %% [markdown]
# ### encapsulation

# %%
class Mobile:
    def __init__(self, name, model, imei):
        self.name = name
        self.model = model
        self.__imei = imei   # private variable

    def charge(self):
        print("phone is charging")

    def imei_getter(self): # imei acces korar jonno .jeta kina already privte
        return self.__imei

    def imei_setter(self,new_imei): # acces kore emei change korar jonno
        self.__imei=new_imei


iphone = Mobile("IPHONE", 12, "13diwiew")
print(iphone.imei_getter())
iphone.imei_setter("123456789")
print(iphone.imei_getter())
# Out:
# 13diwiew
# 123456789

# %% [markdown]
# ### abstraction

# %%
from abc import ABC, abstractmethod

## Abstract class
class Vehical(ABC):

  @abstractmethod
  def run(self):
    pass

     

class Car(Vehical):
  def start(self):
    print("Car is starting")

  def run(self):
    print("Car is running")


car1 = Car()
car1.run()
# Out:
# Car is running

# %%
# Abstraction Class

class BankService(ABC):
  def run(self):
    print("running")
  @abstractmethod
  def transaction(self):
    pass

class Account:
    bank_name ="Phitron Bank"

    def __init__(self, name, account_no, balance):
        self.name = name
        self.account_no = account_no
        self.__balance = balance # Private Attribute

    def get_balance(self):
      return self.__balance

    def deposite(self, money):
       # extra security
        self.__balance += money
        return f"{money} is added, New Balance is: {self.__balance}"

    def withdraw(self, withdrawMoney):
        if withdrawMoney > self.__balance:
            return f"Insufficient Balance"
        else:
           self.__balance -= withdrawMoney
           return f"{withdrawMoney} is Withdrawed, New Balance is: {self.__balance}"


class SavingAccount(Account):
  def __init__(self, name, account_no, balance, interest_rate):
        super().__init__(name, account_no, balance)
        self.interest_rate = interest_rate

  def calculate_interest_rate(self):
    interest = self.get_balance() * self.interest_rate / 100
    return f"Interest rate is : {interest}"

class CurrentAccount(Account):
  def __init__(self, name, account_no, balance, overlimit):
        super().__init__(name, account_no, balance)
        self.overlimit = overlimit

  def withdraw(self, withdrawMoney):
    if withdrawMoney > self.get_balance() + self.overlimit :
            return f"Insufficient Balance for Current Account user"
    balance = self.get_balance() - withdrawMoney
    return f"{withdrawMoney} is withdrawed , new balance is {balance}"


class ATM(BankService):
  def transaction(self):
     print("Transaction by ATM")

  def withdraw(self):
    print("Withdraw")

class VisaCard(BankService):
  def transaction(self):
     super().transaction()
     print("Transaction by VisaCard")


current1 = CurrentAccount("C", 124, 100, 500)
current1.withdraw(1000)

saving1 = SavingAccount("R", 123, 5000, 0.9)
saving1.get_balance()
print(saving1.calculate_interest_rate())
saving1.withdraw(10)
# Out:
# Interest rate is : 45.0
# '10 is Withdrawed, New Balance is: 4990'

# %%
class Account:
    bank_name="ISLAMI BANK LTD"
    def __init__(self,name, account_no, balance):
        self.name=name
        self.account_no=account_no
        self.__balance=balance

    def get_balance(self):
        return self.__balance

ss=Account("SAYED",123,1090)
print(ss.get_balance)      
print(ss.get_balance())
# Out:
# <bound method Account.get_balance of <__main__.Account object at 0x0000021B0A3D8AD0>>
# 1090

# %%
class Account:
    bank_name="ISLAMI BANK LTD"
    def __init__(self,name, account_no, balance):
        self.name=name
        self.account_no=account_no
        self.__balance=balance

    def get_balance(self):
        return self.__balance
    
    def deposite(self,money):
        self.__balance+=money
        return f"{money} is added ,new balace is : {self.__balance}"
    
    def withdraw(self,withdraw_money):
        if withdraw_money>self.__balance:
            return f"insufficient Balance"
        else:
           self.__balance -= withdraw_money
           return f"{withdraw_money} is Withdrawed, New Balance is: {self.__balance}"
             

class saving_account(Account):
    def __init__(self, name, account_no, balance,interest_rate):
        super().__init__(name, account_no, balance)
        self.interest_rate=interest_rate

    def calculate_interest_rate(self):
         interest = self.get_balance() * self.interest_rate / 100
         return f"Interest rate is : {interest}"              
            
st=saving_account("sa",1233,100,2)
print(st.calculate_interest_rate())

class current_account(Account):
    def __init__(self, name, account_no, balance,over_limit):
        super().__init__(name, account_no, balance)
        self.over_limit=over_limit


    def withdraw(self, withdraw_money):
        if withdraw_money > self.get_balance() + self.over_limit:

           return f"Insufficient Balance for Current Account user"
        else:

           balance = self.get_balance()-withdraw_money
           return f"{withdraw_money} is withdrawed , new balance is {balance}" 


sa = saving_account("Sayed", 1233, 100, 2)

print(sa.get_balance())           
# 100  
# 👉 Account class এর get_balance()

print(sa.deposite(50))            
# 50 is added, New balance is: 150  
# 👉 Account class এর deposite()

print(sa.withdraw(30))            
# 30 is Withdrawn, New Balance is: 120  
# 👉 Account class এর withdraw()

print(sa.calculate_interest_rate())  
# Interest is: 2.4  
# 👉 saving_account class এর calculate_interest_rate()


ca = current_account("Rahim", 999, 100, 50)

print(ca.withdraw(120))
print(ca.withdraw(200))
# Out:
# Interest rate is : 2.0
# 100
# 50 is added ,new balace is : 150
# 30 is Withdrawed, New Balance is: 120
# Interest rate is : 2.4
# 120 is withdrawed , new balance is -20
# Insufficient Balance for Current Account user
