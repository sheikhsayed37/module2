# %%
def function1(a,b):
    print(f"My name is {a} and I am {b} years old.")
function1("rahin",28)
# Out:
# My name is rahin and I am 28 years old.

# %%
lst=[x for x in range (9)]

def batch_generator(chunk_size,lst):
    for i in range(1,len(lst),chunk_size):
        yield lst[i:i+chunk_size]
s1=batch_generator(3,lst)
print(next(s1))
print(next(s1))
print(next(s1))
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8]

# %%
lst = [1,2,3,4]
squares = list(map(lambda x: x**2, lst))  
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
lst=[1,2,3,4,5]
squares=list(map(lambda x:x**2,lst))
print(squares)
# Out:
# [1, 4, 9, 16, 25]
