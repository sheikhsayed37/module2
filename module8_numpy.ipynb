# %%
arr=[1,2,3]
print(arr*5)
arr=[x*5 for x in arr]
print(arr)

# %%
import numpy as np

arr1 = np.array([1,2,3])

arr1 = arr1 * 5

print(arr1)

# %%
import numpy as np
#1d array
arr1=np.array([1,2,3,4])
#2d array
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
#3d array
arr3=np.array([ #1st floor
              [[1,2,3],[4,5,6]],
              #2nd floor
              [[1,2,3],[4,5,6]],
              #3d array
              [[1,2,3],[4,5,6]]
              ])     

#dimension
print(arr1.ndim)
print(arr2.ndim)
print(arr3.ndim)

#shape
print(arr1.shape)
print(arr2.shape)
print(arr3.shape)

#data type

print(arr1.dtype)
print(arr2.dtype)
print(arr3.dtype)

#size
print(arr1.size)
print(arr2.size)
print(arr3.size)

# %%
arr=np.array([1,2,3,4])
print(arr.dtype)
arr=np.array([1,2,3,4.3])
print(arr.dtype)

# %%
arr = np.array([1,2,3.2])
# upcasted to float
print(arr.dtype)

#upcasted to string
arr = np.array([1,2,3.2,'hello'])
print(arr.dtype)


arr = np.array([1,True,3.25,'hello',])
print(arr.dtype)

# %%
arr=np.array([1,2,300],dtype=np.int16)
print(arr.dtype)
print(arr)
arr=np.astype(np.int32)
print(arr.dtype)

# %%
#list

lst = [10,20,30,40 , 40.5]

arr = np.array(lst, dtype=np.int32)

# print(arr)
# print(type(arr))
# print(arr.dtype)

mixed_lst = [10, True , 'Hello' ]

print(mixed_lst)
arr = np.array(mixed_lst)
# print(arr)
# print(type(arr))
# print(arr.dtype)

matrix = [ [1,2,3], #row1
           [4,5,6]]  #row2                ]

arr = np.array(matrix)

print(arr)
print(type(arr))
print(arr.dtype)
print(arr.shape)
print(arr.ndim)

# %%
arr = np.linspace(0, 4 ,6)


print(arr)
print(type(arr))
print(arr.dtype)
print(arr.shape)
print(arr.ndim)
print(arr.size)

# %%
# np.logspace(start , end(included) , koita )

arr = np.logspace(0 , 4 ,6, base =2)

print(arr)

# %%
diagonal_matrix = np.diag([1,2,3,4])

print(diagonal_matrix)
print(diagonal_matrix.shape)

# %%
print(arr1)
print(arr2)

#print(arr1)

arr2[0][2]=100
print(arr2)

# %%
#slicing
#1d = arr[start:end:step]

arr1_mod=arr1[1:4].copy() # arr1=[1,2,3,4]
arr[1]=19
arr1_mod[2]=200

print(arr1_mod)
print(arr1)

# %%
#slicing
#1d = arr[start:end:step]

arr1_mod = arr1[1:4].copy() #arr1=[1,2,3,4]
arr1[1] = 7


arr1_mod[2] = 200
print(arr1_mod)
print(arr1)

# %%
#2d slicing
# arr[ row_start : row_end : step , column_start : column_end : step ]

# print(arr2)

#getting a row

arr2=np.array([[1,2,3,4],
               [5,6,7,8]])

row_0=arr2[0:1,]
row_1=arr2[1: ,]
print(row_0)
print(row_1)

col_0 = arr2[:: ,0:1]
col_1 = arr2[::,1:2]

print(col_0)
print(col_1)

# %%
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
matrix=arr2[: : ,0:2]
print(matrix)

# %%
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
matrix=arr2[ 0:1,] #row part ta  
print(matrix)

# %%
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
matrix=arr2[0:0]
print(matrix)

# %%
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
matrix=arr2[: : ,1:3]
print(matrix)

# %%
lst = np.array([ 10 , 20 ,30 ,40 ])

values = lst[[0,3,1]]

print(values)

# %%
arr2=np.array([[1,2,3,4],
               [5,6,7,8]])
print(arr2)
print(arr2[[0,1] , [1,2]]) #kon index ta 


print(arr2[arr2>1])

arr2[arr2>2] = 0 # arr2 te 2 teke boro jara ase bad dia 0 kore daw


print(arr2)

# %%
arr  = np.array([[10,20,30] , [100,200,300] ] )

# iteration
print(arr3)
for i in np.nditer(arr3):
    print(i)
